# %%
import pandas as pd

# %%
df = pd.read_csv('C:data/titanic_train.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_name = df[df['Name'] == 'Miss']
df_name.Name.value_counts()
# Out:
# Series([], Name: Name, dtype: int64)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df_fare = df[df['Fare'] > 100]
df_fare1 = df_fare.Fare
df_fare1
#df_fare.Fare.value_counts()
# Out:
# 27     263.0000
# 31     146.5208
# 88     263.0000
# 118    247.5208
# 195    146.5208
# 215    113.2750
# 258    512.3292
# 268    153.4625
# 269    135.6333
# 297    151.5500
# 299    247.5208
# 305    151.5500
# 306    110.8833
# 307    108.9000
# 311    262.3750
# 318    164.8667
# 319    134.5000
# 325    135.6333
# 332    153.4625
# 334    133.6500
# 337    134.5000
# 341    263.0000
# 373    135.6333
# 377    211.5000
# 380    227.5250
# 390    120.0000
# 393    113.2750
# 435    120.0000
# 438    263.0000
# 498    151.5500
# 505    108.9000
# 527    221.7792
# 537    106.4250
# 544    106.4250
# 550    110.8833
# 557    227.5250
# 581    110.8833
# 609    153.4625
# 659    113.2750
# 660    133.6500
# 679    512.3292
# 689    211.3375
# 698    110.8833
# 700    227.5250
# 708    151.5500
# 716    227.5250
# 730    211.3375
# 737    512.3292
# 742    262.3750
# 763    120.0000
# 779    211.3375
# 802    120.0000
# 856    164.8667
# Name: Fare, dtype: float64

# %%
df_fare1.shape
df_fare1.value_counts()
# Out:
# 263.0000    4
# 110.8833    4
# 120.0000    4
# 227.5250    4
# 151.5500    4
# 113.2750    3
# 211.3375    3
# 153.4625    3
# 512.3292    3
# 135.6333    3
# 164.8667    2
# 262.3750    2
# 106.4250    2
# 146.5208    2
# 247.5208    2
# 108.9000    2
# 134.5000    2
# 133.6500    2
# 221.7792    1
# 211.5000    1
# Name: Fare, dtype: int64

# %%
df_age.shape
# Out:
# (577, 12)

# %%
df_age1 = df[(df['Age'] > 20) & (df['Age'] < 30) & (df['Sex'] == 'male') & (df['Pclass'] == 1)]

# %%
df_age1[['Name','Age','Sex','Cabin']]
# Out:
#                                           Name   Age   Sex    Cabin
# 23                Sloper, Mr. William Thompson  28.0  male       A6
# 34                     Meyer, Mr. Edgar Joseph  28.0  male      NaN
# 83                     Carrau, Mr. Francisco M  28.0  male      NaN
# 97             Greenfield, Mr. William Bertram  23.0  male  D10 D12
# 102                  White, Mr. Richard Frasar  21.0  male      D26
# 118                   Baxter, Mr. Quigg Edmond  24.0  male  B58 B60
# 139                         Giglio, Mr. Victor  24.0  male      B86
# 336                  Pears, Mr. Thomas Clinton  29.0  male       C2
# 370                Harder, Mr. George Achilles  25.0  male      E50
# 373                        Ringhini, Mr. Sante  22.0  male      NaN
# 377                  Widener, Mr. Harry Elkins  27.0  male      C82
# 430  Bjornstrom-Steffansson, Mr. Mauritz Hakan  28.0  male      C52
# 484                    Bishop, Mr. Dickinson H  25.0  male      B49
# ...

# %%
df.append['Name' = 'Sravani']
# Out:
#   File "<ipython-input-66-ab2d47c9e3b6>", line 1
#     df.append['Name' = 'Sravani']
#                      ^
# SyntaxError: invalid syntax

# %%
col_names = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race'
             ,'sex','capital-gain','capital-loss','hours-per-week','native-country']

# %%
df_adult = pd.read_csv('C:adult.data.txt',names = col_names)

# %%
df_adult.head()
# Out:
#                   age  workclass      fnlwgt  education        education-num  \
# 39          State-gov      77516   Bachelors         13        Never-married
# 50   Self-emp-not-inc      83311   Bachelors         13   Married-civ-spouse
# 38            Private     215646     HS-grad          9             Divorced
# 53            Private     234721        11th          7   Married-civ-spouse
# 28            Private     338409   Bachelors         13   Married-civ-spouse
#
#         marital-status      occupation relationship     race   sex  \
# 39        Adm-clerical   Not-in-family        White     Male  2174
# 50     Exec-managerial         Husband        White     Male     0
# 38   Handlers-cleaners   Not-in-family        White     Male     0
# 53   Handlers-cleaners         Husband        Black     Male     0
# 28      Prof-specialty            Wife        Black   Female     0
#
#     capital-gain  capital-loss  hours-per-week native-country
# ...

# %%
df_age = df_adult[df_adult['age']>50]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-19eb4cf85642> in <module>()
# ----> 1 df_adult[df_adult['age']>50]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     763
#     764         if is_object_dtype(x.dtype):
# --> 765             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     766         else:
#     767
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     743         result = lib.vec_compare(x, y, op)
#     744     else:
# ...

# %%
df_adult.shape
# Out:
# (32561, 14)

# %%
df_adult.age
# Out:
# 39            State-gov
# 50     Self-emp-not-inc
# 38              Private
# 53              Private
# 28              Private
# 37              Private
# 49              Private
# 52     Self-emp-not-inc
# 31              Private
# 42              Private
# 37              Private
# 30            State-gov
# 23              Private
# 32              Private
# 40              Private
# 34              Private
# 25     Self-emp-not-inc
# 32              Private
# 38              Private
# 43     Self-emp-not-inc
# 40              Private
# 54              Private
# 35          Federal-gov
# 43              Private
# 59              Private
# 56            Local-gov
# 19              Private
# 54                    ?
# 39              Private
# 49              Private
#             ...
# 30                    ?
# 34              Private
# 54              Private
# 37              Private
# 22              Private
# 34              Private
# 30              Private
# ...
