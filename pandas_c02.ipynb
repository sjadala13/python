# %%
iris_col = ['sepal_lenghth_in_cm','sepal_width_in_cm','petal_length_in_cm','petal_depth_in_cm','class']

# %%
import pandas as pd
iris_data = pd.read_csv('C:iris.data.txt',names = iris_col)

# %%
iris_data.head()
# Out:
#    sepal_lenghth_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                  5.1                3.5                 1.4
# 1                  4.9                3.0                 1.4
# 2                  4.7                3.2                 1.3
# 3                  4.6                3.1                 1.5
# 4                  5.0                3.6                 1.4
#
#    petal_depth_in_cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
iris_setos = iris_data[iris_data['class']== 'Iris-setosa']

# %%
iris_setos
# Out:
#     sepal_lenghth_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# 5                   5.4                3.9                 1.7
# 6                   4.6                3.4                 1.4
# 7                   5.0                3.4                 1.5
# 8                   4.4                2.9                 1.4
# 9                   4.9                3.1                 1.5
# 10                  5.4                3.7                 1.5
# 11                  4.8                3.4                 1.6
# 12                  4.8                3.0                 1.4
# 13                  4.3                3.0                 1.1
# ...

# %%
iris_data[(iris_data['class'] == 'Iris-setosa') & (iris_data['sepal_lenghth_in_cm'] > 3]
# Out:
# Empty DataFrame
# Columns: [sepal_lenghth_in_cm, sepal_width_in_cm, petal_length_in_cm, petal_depth_in_cm, class]
# Index: []

# %%
iris_data['class'] .value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# ...
