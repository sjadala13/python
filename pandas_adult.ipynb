# %%
col_names = ['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race'
             ,'sex','capital_gain','capital_loss','hours_per_week','native_country','class']
import pandas as pd
data_adult = pd.read_csv('C:adult.data.txt',names = col_names)

# %%
data_adult.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data_adult.education
# Out:
# 0            Bachelors
# 1            Bachelors
# 2              HS-grad
# 3                 11th
# 4            Bachelors
# 5              Masters
# 6                  9th
# 7              HS-grad
# 8              Masters
# 9            Bachelors
# 10        Some-college
# 11           Bachelors
# 12           Bachelors
# 13          Assoc-acdm
# 14           Assoc-voc
# 15             7th-8th
# 16             HS-grad
# 17             HS-grad
# 18                11th
# 19             Masters
# 20           Doctorate
# 21             HS-grad
# 22                 9th
# 23                11th
# 24             HS-grad
# 25           Bachelors
# 26             HS-grad
# 27        Some-college
# 28             HS-grad
# 29             HS-grad
#              ...
# 32531        Bachelors
# 32532        Doctorate
# 32533        Bachelors
# 32534     Some-college
# 32535             12th
# 32536        Bachelors
# 32537          HS-grad
# 32538        Bachelors
# 32539        Doctorate
# ...

# %%
edu_ms = data_adult['education'] == 'Bachelors'

# %%
edu_ms['education']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-adb8afce9de1> in <module>()
# ----> 1 edu_ms['education']
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2475         try:
# ...

# %%
edu_num = data_adult[(data_adult['education_num'] >9) & (data_adult['education_num'] < 13)]

# %%
edu_num[['education_num','education']]
# Out:
#        education_num      education
# 10                10   Some-college
# 13                12     Assoc-acdm
# 14                11      Assoc-voc
# 27                10   Some-college
# 30                12     Assoc-acdm
# 31                10   Some-college
# 33                10   Some-college
# 34                10   Some-college
# 36                10   Some-college
# 38                10   Some-college
# 39                12     Assoc-acdm
# 48                11      Assoc-voc
# 49                11      Assoc-voc
# 50                10   Some-college
# 55                10   Some-college
# 57                11      Assoc-voc
# 64                10   Some-college
# 66                10   Some-college
# 68                10   Some-college
# 69                10   Some-college
# 70                10   Some-college
# 73                10   Some-college
# 74                10   Some-college
# 76                12     Assoc-acdm
# 90                11      Assoc-voc
# ...

# %%
data_edu = data_adult['education'] == 'Masters'

# %%
data_edu.value_counts()
# Out:
# False    32561
# Name: education, dtype: int64

# %%
data_edu[['education','sex']][:25]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-c3ddc4a6b75e> in <module>()
# ----> 1 data_edu[['education','sex']][:25]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     681                     # handle the dup indexing case (GH 4246)
#     682                     if isinstance(key, (list, tuple)):
# --> 683                         return self.loc[key]
#     684
#     685                     return self.reindex(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1326         else:
# ...

# %%
data_age = data_adult[(data_adult['age']>50) & (data_adult['sex'] == 'Male') ]

# %%
data_age[['age','education']]
# Out:
# Empty DataFrame
# Columns: [age, education]
# Index: []

# %%
data_adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'class'],
#       dtype='object')

# %%
df_rs = data_adult['relationship'] == 'Husband'

# %%
df_rs.value_counts()
# Out:
# False    32561
# Name: relationship, dtype: int64

# %%
data_adult.relationship[:23]
# Out:
# 0      Not-in-family
# 1            Husband
# 2      Not-in-family
# 3            Husband
# 4               Wife
# 5               Wife
# 6      Not-in-family
# 7            Husband
# 8      Not-in-family
# 9            Husband
# 10           Husband
# 11           Husband
# 12         Own-child
# 13     Not-in-family
# 14           Husband
# 15           Husband
# 16         Own-child
# 17         Unmarried
# 18           Husband
# 19         Unmarried
# 20           Husband
# 21         Unmarried
# 22           Husband
# Name: relationship, dtype: object

# %%
data_adult['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
data_edu = data_adult['education'] == '11th'

# %%
data_edu.value_counts()
# Out:
# False    32561
# Name: education, dtype: int64

# %%
data_edu[['education','sex']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-3812ab840697> in <module>()
# ----> 1 data_edu[['education','sex']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     681                     # handle the dup indexing case (GH 4246)
#     682                     if isinstance(key, (list, tuple)):
# --> 683                         return self.loc[key]
#     684
#     685                     return self.reindex(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1326         else:
# ...
